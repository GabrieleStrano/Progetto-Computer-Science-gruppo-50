# %% [markdown]
# You have to work on the University dataset. It contains three different university rankings:
#
#     The Times Higher Education World University Ranking, shortly Times,
#     the Academic Ranking of World Universities, shortly Shanghai,
#     the Center for World University Rankings, shortly cwur.
#
# Notes
#
#     It is mandatory to use GitHub for developing the project.
#     The project must be a jupyter notebook.
#     There is no restriction on the libraries that can be used, nor on the Python version.
#     All questions on the project must be asked in a public channel on Zulip.

# %%
import pandas as pd
import numpy as np
import re

# %%
from numpy import nan
from numpy import NaN
from numpy import mean

# %%
times = pd.read_csv('2020/timesData.csv', 
                    na_values = '-',
                   thousands= ',')

# %%
shanghai = pd.read_csv('2020/shanghaiData.csv')
shanghai.head(10)
# Out:
#   world_rank                              university_name national_rank  \
# 0          1                           Harvard University             1
# 1          2                      University of Cambridge             1
# 2          3                          Stanford University             2
# 3          4           University of California, Berkeley             3
# 4          5  Massachusetts Institute of Technology (MIT)             4
# 5          6           California Institute of Technology             5
# 6          7                          Columbia University             6
# 7          8                         Princeton University             7
# 8          9                        University of Chicago             8
# 9         10                         University of Oxford             2
#
#    total_score  alumni  award   hici     ns    pub    pcp  year
# 0        100.0   100.0  100.0  100.0  100.0  100.0   72.4  2005
# ...

# %%
cwur = pd.read_csv('2020/cwurData.csv')
cwur.head(10)
# Out:
#    world_rank                            institution         country  \
# 0           1                     Harvard University             USA
# 1           2  Massachusetts Institute of Technology             USA
# 2           3                    Stanford University             USA
# 3           4                University of Cambridge  United Kingdom
# 4           5     California Institute of Technology             USA
# 5           6                   Princeton University             USA
# 6           7                   University of Oxford  United Kingdom
# 7           8                        Yale University             USA
# 8           9                    Columbia University             USA
# 9          10     University of California, Berkeley             USA
#
#    national_rank  quality_of_education  alumni_employment  quality_of_faculty  \
# 0              1                     7                  9                   1
# ...

# %% [markdown]
# # 1. For each university, extract from the times dataset the most recent and the least recent data, obtaining two separate dataframes

# %%
recenti = times.loc[times.groupby('university_name')['year'].idxmax()]
recenti.head()
# Out:
#      world_rank                           university_name         country  \
# 2405    601-800  AGH University of Science and Technology          Poland
# 2003    201-250                        Aalborg University         Denmark
# 2056    251-300                          Aalto University         Finland
# 1908       =106                         Aarhus University         Denmark
# 2105    301-350                    Aberystwyth University  United Kingdom
#
#       teaching  international  research  citations  income  total_score  \
# 2405      14.2           17.9       3.7       35.7     NaN          NaN
# 2003      25.1           71.0      28.4       73.8    43.7          NaN
# 2056      31.1           65.4      32.8       62.1    61.6          NaN
# 1908      36.9           76.8      50.7       79.8    68.3         57.7
# 2105      21.6           72.2      18.9       67.2    31.3          NaN
#
#       num_students  student_staff_ratio international_students  \
# ...

# %%
meno_recenti = times.loc[times.groupby('university_name')['year'].idxmin()]
meno_recenti.head()
# Out:
#      world_rank                           university_name         country  \
# 2405    601-800  AGH University of Science and Technology          Poland
# 501     301-350                        Aalborg University         Denmark
# 502     301-350                          Aalto University         Finland
# 166         167                         Aarhus University         Denmark
# 476     276-300                    Aberystwyth University  United Kingdom
#
#       teaching  international  research  citations  income  total_score  \
# 2405      14.2           17.9       3.7       35.7     NaN          NaN
# 501       19.0           75.3      20.0       27.1    36.4          NaN
# 502       26.2           49.0      22.2       37.5    61.9          NaN
# 166       38.1           33.4      55.6       57.3    61.5         49.9
# 476       19.8           63.8      15.5       56.6    35.5          NaN
#
#       num_students  student_staff_ratio international_students  \
# ...

# %% [markdown]
# # 2. For each university, compute the improvement in income between the least recent and the most recent data points

# %%
fuso_times = pd.merge(recenti, meno_recenti, on = ['university_name'])
fuso_times.head()
# Out:
#   world_rank_x                           university_name       country_x  \
# 0      601-800  AGH University of Science and Technology          Poland
# 1      201-250                        Aalborg University         Denmark
# 2      251-300                          Aalto University         Finland
# 3         =106                         Aarhus University         Denmark
# 4      301-350                    Aberystwyth University  United Kingdom
#
#    teaching_x  international_x  research_x  citations_x  income_x  \
# 0        14.2             17.9         3.7         35.7       NaN
# 1        25.1             71.0        28.4         73.8      43.7
# 2        31.1             65.4        32.8         62.1      61.6
# 3        36.9             76.8        50.7         79.8      68.3
# 4        21.6             72.2        18.9         67.2      31.3
#
#    total_score_x  num_students_x  ...  international_y research_y citations_y  \
# ...

# %%
fuso_times['differenza'] = fuso_times['income_x'] - fuso_times['income_y']
fuso_times.head()
# Out:
#   world_rank_x                           university_name       country_x  \
# 0      601-800  AGH University of Science and Technology          Poland
# 1      201-250                        Aalborg University         Denmark
# 2      251-300                          Aalto University         Finland
# 3         =106                         Aarhus University         Denmark
# 4      301-350                    Aberystwyth University  United Kingdom
#
#    teaching_x  international_x  research_x  citations_x  income_x  \
# 0        14.2             17.9         3.7         35.7       NaN
# 1        25.1             71.0        28.4         73.8      43.7
# 2        31.1             65.4        32.8         62.1      61.6
# 3        36.9             76.8        50.7         79.8      68.3
# 4        21.6             72.2        18.9         67.2      31.3
#
#    total_score_x  num_students_x  ...  research_y citations_y income_y  \
# ...

# %%
fuso_times[['university_name', 'differenza']]
# Out:
#                               university_name  differenza
# 0    AGH University of Science and Technology         NaN
# 1                          Aalborg University         7.3
# 2                            Aalto University        -0.3
# 3                           Aarhus University         6.8
# 4                      Aberystwyth University        -4.2
# ..                                        ...         ...
# 813                  École Normale Supérieure         6.4
# 814          École Normale Supérieure de Lyon         5.6
# 815                       École Polytechnique         NaN
# 816  École Polytechnique Fédérale de Lausanne        27.4
# 817                         Örebro University         0.0
#
# [818 rows x 2 columns]

# %% [markdown]
# # 3. Find the university with the largest increase computed in the previous point

# %%
fuso_times.loc[fuso_times['differenza'].idxmax()][['university_name', 'differenza']]
# Out:
# university_name    TU Dresden
# differenza               67.8
# Name: 428, dtype: object

# %%
fuso_times.loc[fuso_times['differenza'] >= fuso_times['differenza'].max()]
#verifico presenza di eventuali altri massimi
# Out:
#     world_rank_x university_name country_x  teaching_x  international_x  \
# 428         =158      TU Dresden   Germany        41.4             47.7
#
#      research_x  citations_x  income_x  total_score_x  num_students_x  ...  \
# 428        45.8         66.1      99.7           52.1         35487.0  ...
#
#      research_y citations_y income_y  total_score_y num_students_y  \
# 428        13.8        57.4     31.9            NaN        35487.0
#
#     student_staff_ratio_y  international_students_y  female_male_ratio_y  \
# 428                  37.4                       12%              42 : 58
#
#      year_y  differenza
# 428    2012        67.8
#
# [1 rows x 28 columns]

# %% [markdown]
# # 4. For each ranking, consider only the most recent data point. For each university, compute the maximum difference between the rankings (e.g. for Aarhus University the value is 122-73=49). Notice that some rankings are expressed as a range

# %%
recenti["wr_min"] = recenti['world_rank'].str.extract("=*(\d+)-*").astype(float)
recenti["wr_max"] = recenti["world_rank"].str.extract("-(\d+)").astype(float)

# %%
recenti['wr_max'] = np.where((recenti['wr_max']>= 0), recenti['wr_max'], recenti['wr_min'])
recenti.head()
# Out:
#      world_rank                           university_name         country  \
# 2405    601-800  AGH University of Science and Technology          Poland
# 2003    201-250                        Aalborg University         Denmark
# 2056    251-300                          Aalto University         Finland
# 1908       =106                         Aarhus University         Denmark
# 2105    301-350                    Aberystwyth University  United Kingdom
#
#       teaching  international  research  citations  income  total_score  \
# 2405      14.2           17.9       3.7       35.7     NaN          NaN
# 2003      25.1           71.0      28.4       73.8    43.7          NaN
# 2056      31.1           65.4      32.8       62.1    61.6          NaN
# 1908      36.9           76.8      50.7       79.8    68.3         57.7
# 2105      21.6           72.2      18.9       67.2    31.3          NaN
#
#       num_students  student_staff_ratio international_students  \
# ...

# %%
recenti['wr'] = (recenti['wr_min'] + recenti['wr_max'])/2
recenti.head()
# Out:
#      world_rank                           university_name         country  \
# 2405    601-800  AGH University of Science and Technology          Poland
# 2003    201-250                        Aalborg University         Denmark
# 2056    251-300                          Aalto University         Finland
# 1908       =106                         Aarhus University         Denmark
# 2105    301-350                    Aberystwyth University  United Kingdom
#
#       teaching  international  research  citations  income  total_score  \
# 2405      14.2           17.9       3.7       35.7     NaN          NaN
# 2003      25.1           71.0      28.4       73.8    43.7          NaN
# 2056      31.1           65.4      32.8       62.1    61.6          NaN
# 1908      36.9           76.8      50.7       79.8    68.3         57.7
# 2105      21.6           72.2      18.9       67.2    31.3          NaN
#
#       num_students  student_staff_ratio international_students  \
# ...

# %%
recenti_shanghai = shanghai.loc[shanghai.groupby('university_name')['year'].idxmax()]
recenti_shanghai.head(3)
# Out:
#      world_rank     university_name national_rank  total_score  alumni  award  \
# 4697    301-400  Aalborg University             5          NaN     0.0    0.0
# 4797    401-500    Aalto University           4-6          NaN     0.0    0.0
# 4469         73   Aarhus University             2         27.3    11.5   22.1
#
#       hici    ns   pub   pcp  year
# 4697  11.2   4.6  30.4  16.8  2015
# 4797   0.0  10.4  33.4  17.0  2015
# 4469  12.3  25.8  51.8  31.0  2015

# %%
recenti_shanghai["wr_min"] = recenti_shanghai["world_rank"].str.extract("(\d+)-*").astype(float)
recenti_shanghai["wr_max"] = recenti_shanghai["world_rank"].str.extract("-(\d+)").astype(float)

# %%
recenti_shanghai['wr_max'] = np.where((recenti_shanghai['wr_max']>= 0), recenti_shanghai['wr_max'], recenti_shanghai['wr_min'])
recenti_shanghai.head(3)
# Out:
#      world_rank     university_name national_rank  total_score  alumni  award  \
# 4697    301-400  Aalborg University             5          NaN     0.0    0.0
# 4797    401-500    Aalto University           4-6          NaN     0.0    0.0
# 4469         73   Aarhus University             2         27.3    11.5   22.1
#
#       hici    ns   pub   pcp  year  wr_min  wr_max
# 4697  11.2   4.6  30.4  16.8  2015   301.0   400.0
# 4797   0.0  10.4  33.4  17.0  2015   401.0   500.0
# 4469  12.3  25.8  51.8  31.0  2015    73.0    73.0

# %%
recenti_shanghai['wr'] = (recenti_shanghai['wr_min'] + recenti_shanghai['wr_max'])/2
recenti_shanghai.head(3)
# Out:
#      world_rank     university_name national_rank  total_score  alumni  award  \
# 4697    301-400  Aalborg University             5          NaN     0.0    0.0
# 4797    401-500    Aalto University           4-6          NaN     0.0    0.0
# 4469         73   Aarhus University             2         27.3    11.5   22.1
#
#       hici    ns   pub   pcp  year  wr_min  wr_max     wr
# 4697  11.2   4.6  30.4  16.8  2015   301.0   400.0  350.5
# 4797   0.0  10.4  33.4  17.0  2015   401.0   500.0  450.5
# 4469  12.3  25.8  51.8  31.0  2015    73.0    73.0   73.0

# %%
recenti_cwur = cwur.loc[cwur.groupby('institution')['year'].idxmax()]
recenti_cwur.head(3)
# Out:
#       world_rank                               institution  country  \
# 1981         782  AGH University of Science and Technology   Poland
# 1764         565                        Aalborg University  Denmark
# 1620         421                          Aalto University  Finland
#
#       national_rank  quality_of_education  alumni_employment  \
# 1981              4                   267                279
# 1764              5                   367                439
# 1620              4                   367                224
#
#       quality_of_faculty  publications  influence  citations  broad_impact  \
# 1981                 218           708        891        511         896.0
# 1764                 218           596        660        287         520.0
# 1620                 218           336        403        645         424.0
#
#       patents  score  year
# 1981      398  44.26  2015
# 1764      401  44.59  2015
# 1620      246  45.10  2015

# %%
recenti_2rank = pd.merge(recenti, recenti_shanghai, on='university_name', how='outer')
recenti_2rank.head(3)
# Out:
#   world_rank_x                           university_name  country  teaching  \
# 0      601-800  AGH University of Science and Technology   Poland      14.2
# 1      201-250                        Aalborg University  Denmark      25.1
# 2      251-300                          Aalto University  Finland      31.1
#
#    international  research  citations  income  total_score_x  num_students  \
# 0           17.9       3.7       35.7     NaN            NaN       35569.0
# 1           71.0      28.4       73.8    43.7            NaN       17422.0
# 2           65.4      32.8       62.1    61.6            NaN       16099.0
#
#    ...  alumni award  hici    ns   pub   pcp  year_y wr_min_y wr_max_y   wr_y
# 0  ...     NaN   NaN   NaN   NaN   NaN   NaN     NaN      NaN      NaN    NaN
# 1  ...     0.0   0.0  11.2   4.6  30.4  16.8  2015.0    301.0    400.0  350.5
# 2  ...     0.0   0.0   0.0  10.4  33.4  17.0  2015.0    401.0    500.0  450.5
#
# [3 rows x 30 columns]

# %%
recenti_3rank = pd.merge(recenti_2rank, recenti_cwur, left_on=('university_name','country'), right_on=('institution','country'), how='left')
recenti_3rank.head(3)
# Out:
#   world_rank_x                           university_name  country  teaching  \
# 0      601-800  AGH University of Science and Technology   Poland      14.2
# 1      201-250                        Aalborg University  Denmark      25.1
# 2      251-300                          Aalto University  Finland      31.1
#
#    international  research  citations_x  income  total_score_x  num_students  \
# 0           17.9       3.7         35.7     NaN            NaN       35569.0
# 1           71.0      28.4         73.8    43.7            NaN       17422.0
# 2           65.4      32.8         62.1    61.6            NaN       16099.0
#
#    ...  quality_of_education alumni_employment quality_of_faculty  \
# 0  ...                 267.0             279.0              218.0
# 1  ...                 367.0             439.0              218.0
# 2  ...                 367.0             224.0              218.0
#
#    publications  influence  citations_y  broad_impact patents  score    year
# ...

# %%
rec_3rank = recenti_3rank[['university_name','institution', 'country', 'wr_x', 'wr_y', 'world_rank']]
rec_3rank.head(3)
# Out:
#                             university_name  \
# 0  AGH University of Science and Technology
# 1                        Aalborg University
# 2                          Aalto University
#
#                                 institution  country   wr_x   wr_y  world_rank
# 0  AGH University of Science and Technology   Poland  700.5    NaN       782.0
# 1                        Aalborg University  Denmark  225.5  350.5       565.0
# 2                          Aalto University  Finland  275.5  450.5       421.0

# %%
rec_3rank.loc[((rec_3rank['wr_x'].isnull()) & (rec_3rank['wr_y'].isnull()))]
# Out:
# Empty DataFrame
# Columns: [university_name, institution, country, wr_x, wr_y, world_rank]
# Index: []

# %%
rec_3rank.loc[((rec_3rank['wr_x'].isnull()) | (rec_3rank['wr_y'].isnull())) & (rec_3rank['world_rank'].isnull())]
#quante colonne hanno missing value in 2 rank su 3 (tra wr_x e we_y abbiamo già verificato)
# Out:
#                                         university_name institution  \
# 5                            Adam Mickiewicz University         NaN
# 9                        Alexandru Ioan Cuza University         NaN
# 10                            Aligarh Muslim University         NaN
# 11                                  American University         NaN
# 13                       American University of Sharjah         NaN
# ...                                                 ...         ...
# 1087                           West Virginia University         NaN
# 1088                                 Western University         NaN
# 1089  Western University (The University of Western ...         NaN
# 1090                          Xian Jiao Tong University         NaN
# 1091                               Yamaguchi University         NaN
#
#                        country   wr_x   wr_y  world_rank
# 5                       Poland  700.5    NaN         NaN
# ...

# %%
rec_3rank = rec_3rank.drop(rec_3rank[((rec_3rank['wr_x'].isnull()) | (rec_3rank['wr_y'].isnull())) & (rec_3rank['world_rank'].isnull())].index)
#rimuovo le righe con 2 missing values su 3 colonne

# %%
rec_3rank['max'] = rec_3rank[['wr_x', 'wr_y', 'world_rank']].max(axis=1)
rec_3rank
# Out:
#                               university_name  \
# 0    AGH University of Science and Technology
# 1                          Aalborg University
# 2                            Aalto University
# 3                           Aarhus University
# 4                      Aberystwyth University
# ..                                        ...
# 809                           York University
# 810                        Yuan Ze University
# 812                       Zhejiang University
# 815                       École Polytechnique
# 817                         Örebro University
#
#                                   institution         country   wr_x   wr_y  \
# 0    AGH University of Science and Technology          Poland  700.5    NaN
# 1                          Aalborg University         Denmark  225.5  350.5
# 2                            Aalto University         Finland  275.5  450.5
# 3                           Aarhus University         Denmark  106.0   73.0
# ...

# %%
rec_3rank['rank_difference'] = rec_3rank[['wr_x', 'wr_y', 'world_rank']].max(axis=1) - rec_3rank[['wr_x', 'wr_y', 'world_rank']].min(axis=1)

# %%
rec_3rank[['university_name', 'rank_difference']]
# Out:
#                               university_name  rank_difference
# 0    AGH University of Science and Technology             81.5
# 1                          Aalborg University            339.5
# 2                            Aalto University            175.0
# 3                           Aarhus University             49.0
# 4                      Aberystwyth University            488.5
# ..                                        ...              ...
# 809                           York University            125.0
# 810                        Yuan Ze University            278.5
# 812                       Zhejiang University            150.0
# 815                       École Polytechnique             65.0
# 817                         Örebro University            313.5
#
# [576 rows x 2 columns]

# %% [markdown]
# # 5. Consider only the most recent data point of the times dataset. Compute the number of male and female students for each country.

# %%
recenti["f"], recenti["m"] = recenti["female_male_ratio"].str.split(":", 1).str
recenti["f"] = pd.to_numeric(recenti["f"])
recenti["m"] = pd.to_numeric(recenti["m"])
# Out:
# <ipython-input-67-f0c6342843ba>:1: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   recenti["f"], recenti["m"] = recenti["female_male_ratio"].str.split(":", 1).str

# %%
recenti.head(3)
# Out:
#      world_rank                           university_name  country  teaching  \
# 2405    601-800  AGH University of Science and Technology   Poland      14.2
# 2003    201-250                        Aalborg University  Denmark      25.1
# 2056    251-300                          Aalto University  Finland      31.1
#
#       international  research  citations  income  total_score  num_students  \
# 2405           17.9       3.7       35.7     NaN          NaN       35569.0
# 2003           71.0      28.4       73.8    43.7          NaN       17422.0
# 2056           65.4      32.8       62.1    61.6          NaN       16099.0
#
#       student_staff_ratio international_students female_male_ratio  year  \
# 2405                 17.0                     1%               NaN  2016
# 2003                 15.9                    15%           48 : 52  2016
# 2056                 24.2                    17%           32 : 68  2016
#
#       wr_min  wr_max     wr     f     m
# ...

# %%
recenti['femmine']= (recenti['num_students'] * recenti['f']) / 100
recenti['maschi']= (recenti['num_students'] * recenti['m']) / 100
recenti.head()
# Out:
#      world_rank                           university_name         country  \
# 2405    601-800  AGH University of Science and Technology          Poland
# 2003    201-250                        Aalborg University         Denmark
# 2056    251-300                          Aalto University         Finland
# 1908       =106                         Aarhus University         Denmark
# 2105    301-350                    Aberystwyth University  United Kingdom
#
#       teaching  international  research  citations  income  total_score  \
# 2405      14.2           17.9       3.7       35.7     NaN          NaN
# 2003      25.1           71.0      28.4       73.8    43.7          NaN
# 2056      31.1           65.4      32.8       62.1    61.6          NaN
# 1908      36.9           76.8      50.7       79.8    68.3         57.7
# 2105      21.6           72.2      18.9       67.2    31.3          NaN
#
#       num_students  ...  international_students female_male_ratio  year  \
# ...

# %%
recenti.groupby('country')['femmine'].sum()
# Out:
# country
# Argentina                      67191.26
# Australia                     391735.88
# Austria                        68364.08
# Bangladesh                     21323.44
# Belarus                        20219.07
#                                 ...
# Unisted States of America          0.00
# United Arab Emirates            9516.44
# United Kingdom                711813.62
# United States of America     1601453.63
# Unted Kingdom                      0.00
# Name: femmine, Length: 72, dtype: float64

# %%
recenti.groupby('country')['maschi'].sum()
# Out:
# country
# Argentina                      41181.74
# Australia                     321640.12
# Austria                        66112.92
# Bangladesh                     41392.56
# Belarus                         9083.93
#                                 ...
# Unisted States of America          0.00
# United Arab Emirates            4930.56
# United Kingdom                613028.38
# United States of America     1556321.37
# Unted Kingdom                      0.00
# Name: maschi, Length: 72, dtype: float64

# %% [markdown]
# # 6. Find the universities where the ratio between female and male is below the average ratio (computed over all universities)

# %%
recenti['ratio'] = recenti['f']/recenti['m']

# %%
recenti['ratio']
# Out:
# 2405         NaN
# 2003    0.923077
# 2056    0.470588
# 1908    1.173913
# 2105    0.923077
#           ...
# 1856    0.851852
# 2013    0.960784
# 1904    0.219512
# 1833    0.369863
# 2134    1.564103
# Name: ratio, Length: 818, dtype: float64

# %%
recenti.loc[recenti['ratio']== np.inf]
#avevo ricevuto un valore infinito dato da un'università interamente femminile (100/0)
# Out:
#      world_rank         university_name      country  teaching  international  \
# 2227    401-500  Ewha Womans University  South Korea      23.9           34.3
#
#       research  citations  income  total_score  num_students  ...  \
# 2227      18.3       50.4    57.6          NaN       17625.0  ...
#
#       female_male_ratio  year wr_min  wr_max     wr      f    m  femmine  \
# 2227            100 : 0  2016  401.0   500.0  450.5  100.0  0.0  17625.0
#
#       maschi  ratio
# 2227     0.0    inf
#
# [1 rows x 22 columns]

# %%
recenti["ratio"].replace({np.inf: 100}, inplace= True)
#ho rimpiazzato quell'unico valore inf con il vero valore della riga cioè 100

# %%
avg_ratio = recenti['ratio'].mean()
avg_ratio
# Out:
# 1.2149571636836496

# %%
recenti.loc[recenti['ratio'] < avg_ratio][['university_name', 'ratio']]
# Out:
#                                university_name     ratio
# 2003                        Aalborg University  0.923077
# 2056                          Aalto University  0.470588
# 1908                         Aarhus University  1.173913
# 2105                    Aberystwyth University  0.923077
# 2406                           Ajou University  0.492537
# ...                                        ...       ...
# 2104                       Zhejiang University  0.694915
# 1856                  École Normale Supérieure  0.851852
# 2013          École Normale Supérieure de Lyon  0.960784
# 1904                       École Polytechnique  0.219512
# 1833  École Polytechnique Fédérale de Lausanne  0.369863
#
# [468 rows x 2 columns]

# %% [markdown]
# # 7. For each country, compute the fraction of the students in the country that are in one of the universities computed in the previous point (that is, the denominator of the ratio is the total number of students over all universities in the country).

# %%
sotto_media = recenti.loc[recenti['ratio'] < avg_ratio]

# %%
df_numeratore = sotto_media.groupby('country')['num_students'].sum()
df_numeratore.head()
# Out:
# country
# Australia     295021.0
# Austria        79242.0
# Bangladesh     62716.0
# Belgium       116129.0
# Brazil        438476.0
# Name: num_students, dtype: float64

# %%
df_denom = recenti.groupby('country')['num_students'].sum()
df_denom.head()
# Out:
# country
# Argentina     108373.0
# Australia     743627.0
# Austria       134477.0
# Bangladesh     62716.0
# Belarus        29303.0
# Name: num_students, dtype: float64

# %%
unito = pd.merge(df_numeratore, df_denom, on= 'country')
unito['results'] = unito['num_students_x'] / unito['num_students_y']
unito.head()
# Out:
#             num_students_x  num_students_y   results
# country
# Australia         295021.0        743627.0  0.396733
# Austria            79242.0        134477.0  0.589261
# Bangladesh         62716.0         62716.0  1.000000
# Belgium           116129.0        169661.0  0.684477
# Brazil            438476.0        534688.0  0.820060

# %% [markdown]
# # 8. Read the file educational_attainment_supplementary_data.csv, discarding any row with missing country_name or series_name.

# %%
ed_att_sup = pd.read_csv('2020/educational_attainment_supplementary_data.csv')
ed_att_sup[['country_name', 'series_name']].tail()
# Out:
#                                             country_name series_name
# 79050                                                NaN         NaN
# 79051                                                NaN         NaN
# 79052                                                NaN         NaN
# 79053  Data from database: Education Statistics: Educ...         NaN
# 79054                           Last Updated: 10/20/2015         NaN

# %%
ed_att_sup.dropna(subset=['country_name', 'series_name'], inplace= True)

# %% [markdown]
# # 9. From attainment build a dataframe with the same data, but with 4 columns: country_name, series_name, year, value

# %%
ed_att_sup.head(3)
# Out:
#   country_name                                        series_name  1985  1986  \
# 0  Afghanistan  Barro-Lee: Average years of primary schooling,...  0.33   NaN
# 1  Afghanistan  Barro-Lee: Average years of primary schooling,...  1.03   NaN
# 2  Afghanistan  Barro-Lee: Average years of primary schooling,...  0.83   NaN
#
#    1987  1990  1991  1992  1993  1995  ...  2005  2006  2007  2008  2009  \
# 0   NaN  0.44   NaN   NaN   NaN  0.57  ...  0.86   NaN   NaN   NaN   NaN
# 1   NaN  1.26   NaN   NaN   NaN  1.54  ...  2.18   NaN   NaN   NaN   NaN
# 2   NaN  0.95   NaN   NaN   NaN  1.26  ...  1.01   NaN   NaN   NaN   NaN
#
#    2010  2011  2012  2013  2015
# 0  1.27   NaN   NaN   NaN   NaN
# 1  2.64   NaN   NaN   NaN   NaN
# 2  2.45   NaN   NaN   NaN   NaN
#
# [3 rows x 29 columns]

# %%
new_att = pd.melt(ed_att_sup, id_vars=['country_name', 'series_name'], value_vars=['1985', '1986', '1987', '1990', '1991',
       '1992', '1993', '1995', '1996', '1997', '1998', '1999', '2000', '2001',
       '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010',
       '2011', '2012', '2013', '2015'], var_name= 'year')
new_att.head()
# Out:
#   country_name                                        series_name  year  value
# 0  Afghanistan  Barro-Lee: Average years of primary schooling,...  1985   0.33
# 1  Afghanistan  Barro-Lee: Average years of primary schooling,...  1985   1.03
# 2  Afghanistan  Barro-Lee: Average years of primary schooling,...  1985   0.83
# 3  Afghanistan  Barro-Lee: Average years of primary schooling,...  1985   2.34
# 4  Afghanistan  Barro-Lee: Average years of primary schooling,...  1985   0.54

# %% [markdown]
# # 10. For each university, find the number of rankings in which they appear (it suffices to appear in one year for each ranking).

# %%
appearence_of_university_in_rankings = dict()
times_university = set(times["university_name"])
shanghai_university = set(shanghai["university_name"])
cwur_univeristy = set(cwur["institution"])

# %%
for university in times_university:
    appearence_of_university_in_rankings[university] = 1
for university in shanghai_university:
    if university not in appearence_of_university_in_rankings:
        appearence_of_university_in_rankings[university] = 1
    else:
        appearence_of_university_in_rankings[university] += 1
for university in cwur_univeristy:
    if university not in appearence_of_university_in_rankings:
        appearence_of_university_in_rankings[university] = 1
    else:
        appearence_of_university_in_rankings[university] += 1

# %%
appearence_of_university_in_rankings
# Out:
# {'Linköping University': 2,
#  'Aristotle University of Thessaloniki': 3,
#  'York University': 3,
#  'Yıldız Technical University': 1,
#  'University of Greifswald': 3,
#  'Hiroshima University': 3,
#  'Tampere University of Technology': 2,
#  'University of Bremen': 3,
#  'University of Pécs': 2,
#  'University of Michigan': 1,
#  'Montana State University': 1,
#  'University of Graz': 3,
#  'Deakin University': 3,
#  'Rice University': 3,
#  'University of Geneva': 3,
#  'University of Hohenheim': 2,
#  'Pennsylvania State University': 1,
#  'University of Eastern Finland': 3,
#  'Yokohama National University': 2,
#  'University of Oregon': 3,
#  'Aligarh Muslim University': 1,
#  'Gifu University': 3,
#  'Texas A&M University': 2,
#  'University of California, Santa Cruz': 3,
#  'Virginia Polytechnic Institute and State University': 3,
#  'Boğaziçi University': 2,
#  'University of Dundee': 2,
#  'Syracuse University': 3,
#  'Yeungnam University': 2,
# ...

# %% [markdown]
# # 11. In the times ranking, compute the number of times each university appears.

# %%
times_count = times.groupby('university_name').size()
times_count
# Out:
# university_name
# AGH University of Science and Technology    1
# Aalborg University                          5
# Aalto University                            5
# Aarhus University                           6
# Aberystwyth University                      5
#                                            ..
# École Normale Supérieure                    6
# École Normale Supérieure de Lyon            6
# École Polytechnique                         6
# École Polytechnique Fédérale de Lausanne    6
# Örebro University                           1
# Length: 818, dtype: int64

# %% [markdown]
# # 12. Find the universities that appear at most twice in the times ranking.

# %%
times_count.loc[times_count <= 2]
# Out:
# university_name
# AGH University of Science and Technology    1
# Adam Mickiewicz University                  1
# Aix-Marseille University                    1
# Ajou University                             1
# Alexandru Ioan Cuza University              1
#                                            ..
# Yokohama City University                    1
# Yokohama National University                1
# Yuan Ze University                          2
# Yıldız Technical University                 1
# Örebro University                           1
# Length: 408, dtype: int64

# %% [markdown]
# # 13. The universities that, in any year, have the same position in all three rankings (they must have the same position in a year).

# %%
times["wr_min"] = times["world_rank"].str.extract("=*(\d+)-*").astype(float)
times["wr_max"] = times["world_rank"].str.extract("-(\d+)").astype(float)
times['wr_max'] = np.where((times['wr_max']>= 0), times['wr_max'], times['wr_min'])

# %%
mini_times = times[['university_name', 'year', 'world_rank', 'wr_min', 'wr_max']]
mini_times.rename(columns={'world_rank': 'wr_times', 'wr_min': 'wr_min_times', 'wr_max': 'wr_max_times'}, inplace=True)

# %%
mini_cwur = cwur[['institution', 'year', 'world_rank']]
mini_cwur.rename(columns={'institution': 'university_name', 'world_rank': 'wr_cwur'}, inplace=True)

# %%
shanghai["world_rank"]
# Out:
# 0             1
# 1             2
# 2             3
# 3             4
# 4             5
#          ...
# 4892    401-500
# 4893    401-500
# 4894    401-500
# 4895    401-500
# 4896    401-500
# Name: world_rank, Length: 4897, dtype: object

# %%
shanghai["wr_min_sha"] = shanghai["world_rank"].str.extract("(\d+)-*").astype(float)
shanghai["wr_max_sha"] = shanghai["world_rank"].str.extract("-(\d+)").astype(float)
shanghai['wr_max_sha'] = np.where((shanghai['wr_max_sha'] >= 0), shanghai['wr_max_sha'], shanghai['wr_min_sha'])

# %%
shanghai['wr_max_sha']
# Out:
# 0         1.0
# 1         2.0
# 2         3.0
# 3         4.0
# 4         5.0
#         ...
# 4892    500.0
# 4893    500.0
# 4894    500.0
# 4895    500.0
# 4896    500.0
# Name: wr_max_sha, Length: 4897, dtype: float64

# %%
mini_sha = shanghai[['university_name', 'year', 'world_rank', 'wr_min_sha', 'wr_max_sha']]
mini_sha.rename(columns={'world_rank': 'wr_sha'}, inplace=True)
mini_sha
# Out:
#                                   university_name  year   wr_sha  wr_min_sha  \
# 0                              Harvard University  2005        1         1.0
# 1                         University of Cambridge  2005        2         2.0
# 2                             Stanford University  2005        3         3.0
# 3              University of California, Berkeley  2005        4         4.0
# 4     Massachusetts Institute of Technology (MIT)  2005        5         5.0
# ...                                           ...   ...      ...         ...
# 4892                        University of Trieste  2015  401-500       401.0
# 4893                       University of Zaragoza  2015  401-500       401.0
# 4894                        Utah State University  2015  401-500       401.0
# 4895              Vienna University of Technology  2015  401-500       401.0
# 4896                       Wake Forest University  2015  401-500       401.0
#
#       wr_max_sha
# 0            1.0
# ...

# %%
df_united = mini_times.merge(mini_cwur.merge(mini_sha, on=('university_name', 'year')), on=('university_name', 'year'))
df_united.head(3)
# Out:
#                       university_name  year wr_times  wr_min_times  \
# 0  California Institute of Technology  2012        1           1.0
# 1                  Harvard University  2012        2           2.0
# 2                 Stanford University  2012        2           2.0
#
#    wr_max_times  wr_cwur wr_sha  wr_min_sha  wr_max_sha
# 0           1.0        5      6         6.0         6.0
# 1           2.0        1      1         1.0         1.0
# 2           2.0        3      2         2.0         2.0

# %%
risultato = df_united.loc[(((df_united['wr_cwur'] >= df_united['wr_min_times']) & (df_united['wr_cwur'] <= df_united['wr_max_times'])) &(((df_united['wr_cwur'] >= df_united['wr_min_sha']) & (df_united['wr_cwur'] <= df_united['wr_max_sha']))))]
#avendo cwur come unico dato puntuale e gli altri due come intervallari, trovo tutte le righe in cui cwur
#sia compreso tra min e max di times e di shanghai

# %%
risultato[['university_name','year', 'wr_times', 'wr_cwur', 'wr_sha']]
# Out:
#                         university_name  year wr_times  wr_cwur   wr_sha
# 60                  Stanford University  2013        2        2        2
# 197           University of Southampton  2014      146      146  101-150
# 302               University of Vermont  2014  301-350      320  301-400
# 315                   Temple University  2014  351-400      390  301-400
# 456                Newcastle University  2015  201-225      212  201-300
# 467  Autonomous University of Barcelona  2015  226-250      241  201-300
# 470                    Laval University  2015  226-250      229  201-300
# 481        Medical University of Vienna  2015  251-275      265  201-300
# 490              University of Waterloo  2015  251-275      269  201-300
# 548                 University of Turku  2015  351-400      383  301-400
